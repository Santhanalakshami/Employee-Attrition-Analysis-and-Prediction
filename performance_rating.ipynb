# %%
#Required Libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the dataset

df= pd.read_csv(r'G:\Python\Employee-Attrition - Employee-Attrition.csv')

# %%
#seeing all columns
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Target Variable for Classification : PerformanceRating

#EDA

plt.figure(figsize=(10, 6))
custom_palette = {3: 'red', 4: 'green'}
sns.countplot(x='PerformanceRating', data=df, palette=custom_palette, hue='PerformanceRating', legend=False)
plt.title('Distribution of Performance Rating')
plt.xlabel('Performance Rating')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

#Observation: The majority of employees have a performance rating of 3, with a smaller proportion rated 4. There are no employees with a performance rating of 1 or 2.

# %%
#Performance Rating with respect to Education Field
plt.figure(figsize=(12, 6))
sns.countplot(x='EducationField', hue='PerformanceRating', data=df, palette='bright')
plt.title('Performance Rating by Education Field')
plt.xlabel('Education Field')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Performance Rating')
plt.show()

#Observation: Employees with a performance rating of 3 & 4 are more prevalent in the Life Sciences fields.

# %%
#PerformanceRating with respect to Gender
plt.figure(figsize=(8, 6))
sns.countplot(x='PerformanceRating', hue='Gender', data=df, palette='dark')
plt.title('Performance Rating by Gender')
plt.xlabel('Performance Rating')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend()
plt.show()  

#Observation: The performance ratings of 3 and 4 are more common among Male employees.

# %%
#Performance Rating with respect to JobRole

plt.figure(figsize=(12, 6))
sns.countplot(x='PerformanceRating', hue='JobRole', data=df, palette='Paired')
plt.title('Performance Rating by Job Role')
plt.xlabel('Performance Rating')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()  

#Observation: Sales Executive has large number of 3 as Performance rating  and Research Scientist has large number of 4 as Performance rating.

# %%
#Performance Rating with respect to Marital Status
sns.countplot(x='PerformanceRating', hue='MaritalStatus', data=df, palette='husl')
plt.title('Performance Rating by Marital Status')
plt.xlabel('Performance Rating')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()  

#Observation : Married Employees has large number of 3&4 as their Performance rating.

# %%
#Binary/Boolean Encoding for Attrition, Gender, Over 18 and Overtime
df['Attrition'] = df['Attrition'].apply(lambda x: 1 if x =='Yes'else 0)
df['Gender'] = df['Gender'].apply(lambda x: 1 if x =='Male'else 0)
df['Over18'] = df['Over18'].apply(lambda x: 1 if x =='Y'else 0)
df['OverTime'] = df['OverTime'].apply(lambda x: 1 if x =='Yes'else 0)

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#one-hot encoding for categorical variables

cat_cols = ['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus']

df = pd.get_dummies(df, columns=cat_cols, prefix=cat_cols, drop_first=False)

# Convert True/False to 1/0
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41          1       1102                 1          2              1
# 1      49          0        279                 8          1              1
# 2      37          1       1373                 2          2              1
# 3      33          0       1392                 3          4              1
# 4      27          0        591                 2          1              1
# ...   ...        ...        ...               ...        ...            ...
# 1465   36          0        884                23          2              1
# 1466   39          0        613                 6          1              1
# 1467   27          0        155                 4          3              1
# 1468   49          0       1023                 2          3              1
# 1469   34          0        628                 8          3              1
#
# ...

# %%
# Numerical Features vs Performance Rating
features = ['Age', 'JobLevel', 'MonthlyIncome', 'PercentSalaryHike', 'YearsAtCompany']

for feature in features:
    plt.figure(figsize=(6, 4))
    custom_palette = {3: 'Salmon', 4: 'lightgreen'}  # colors for the two ratings
    sns.boxplot(x='PerformanceRating', y=feature, data=df, hue='PerformanceRating', palette=custom_palette, legend=False)
    plt.title(f'{feature} vs. Performance Rating')
    plt.xticks([0, 1], ['Rating 3', 'Rating 4'])  # custom labels
    plt.show()

# %%
df = df.drop(['EmployeeCount', 'Over18', 'StandardHours'], axis=1)

#Observation: EmployeeCount, Over18, StandardHours has singe variable, so it doesnt affect the target

# %%
df=df.drop('EmployeeNumber',axis=1)

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0      41          1       1102                 1          2
# 1      49          0        279                 8          1
# 2      37          1       1373                 2          2
# 3      33          0       1392                 3          4
# 4      27          0        591                 2          1
# ...   ...        ...        ...               ...        ...
# 1465   36          0        884                23          2
# 1466   39          0        613                 6          1
# 1467   27          0        155                 4          3
# 1468   49          0       1023                 2          3
# 1469   34          0        628                 8          3
#
#       EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                           2       0          94               3         2
# 1                           3       1          61               2         2
# ...

# %%
#Correlation 

corr = df.corr()
plt.figure(figsize=(16,10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# Top correlated features with PerformanceRating
corr_target = corr['PerformanceRating'].drop('PerformanceRating').sort_values(ascending=False)
print("Top Positive Correlations with PerformanceRating:\n", corr_target.head())
print("\nTop Negative Correlations with PerformanceRating:\n", corr_target.tail())
# Out:
# Top Positive Correlations with PerformanceRating:
#  PercentSalaryHike                    0.773550
# YearsInCurrentRole                   0.034986
# Department_Research & Development    0.032720
# JobRole_Manager                      0.032050
# JobRole_Manufacturing Director       0.029775
# Name: PerformanceRating, dtype: float64
#
# Top Negative Correlations with PerformanceRating:
#  EnvironmentSatisfaction     -0.029548
# Department_Sales            -0.031050
# RelationshipSatisfaction    -0.031351
# JobRole_Research Director   -0.035744
# JobRole_Sales Executive     -0.041401
# Name: PerformanceRating, dtype: float64

# %%
#EDA insights:

# The majority of employees have a performance rating of 3, with a smaller proportion rated 4. There are no employees with a performance rating of 1 or 2.

# Employees with a performance rating of 3 & 4 are more prevalent in the Life Sciences fields.

# The performance ratings of 3 and 4 are more common among Male employees.

# Sales Executive has large number of 3 as Performance rating  and Research Scientist has large number of 4 as Performance rating.

# Married Employees has large number of 3&4 as their Performance rating.

# Top Positive Correlations with PerformanceRating:
#  PercentSalaryHike                    0.773550
# YearsInCurrentRole                   0.034986
# Department_Research & Development    0.032720
# JobRole_Manager                      0.032050
# JobRole_Manufacturing Director       0.029775


# Top Negative Correlations with PerformanceRating:
#  EnvironmentSatisfaction     -0.029548
# Department_Sales            -0.031050
# RelationshipSatisfaction    -0.031351
# JobRole_Research Director   -0.035744
# JobRole_Sales Executive     -0.041401

# %%
# Machine Learning Model

# Split the data into features and target variable

x = df.drop(columns=['PerformanceRating'])
y = df['PerformanceRating']

# %%
# Train-test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Choose a model (logistic regression)

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000, solver='liblinear', class_weight='balanced')
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, solver='liblinear')

# %%
lr_score = lr.score(x_test, y_test)
print(f"Model Score: {lr_score:.4f}")
# Out:
# Model Score: 0.9558

# %%
# Confusion Matrix and Classification Report
from sklearn.metrics import confusion_matrix, classification_report
y_pred = lr.predict(x_test)
cm = confusion_matrix(y_test, y_pred)


import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Spectral', xticklabels=['Rating 3', 'Rating 4'], yticklabels=['Rating 3', 'Rating 4'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

print("Classification Report:\n", classification_report(y_test, y_pred, target_names=['Rating 3', 'Rating 4']))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     Rating 3       1.00      0.95      0.97       251
#     Rating 4       0.78      0.98      0.87        43
#
#     accuracy                           0.96       294
#    macro avg       0.89      0.96      0.92       294
# weighted avg       0.96      0.96      0.96       294

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

lr_pipeline = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('classifier', LogisticRegression(
        solver='lbfgs',
        max_iter=1000,
        class_weight='balanced'
    ))
])

# %%
lr_pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = lr_pipeline.predict(x_test)

y_pred
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 4, 3, 4, 4, 4, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 4, 3, 3, 3,
#        3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3,
#        3, 4, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3,
#        4, 4, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 4, 4, 3, 4, 3, 3, 3, 4, 3,
#        3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 3, 4, 4, 4, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3,
# ...

# %%
# Accuracy score, confusion matrix, and classification report
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print("Accuracy:", accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=lr_pipeline.classes_)
disp.plot(cmap='Reds')
plt.title("Confusion Matrix - Performance Rating Prediction")
plt.show()


print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9795918367346939
# Classification Report:
#                precision    recall  f1-score   support
#
#            3       1.00      0.98      0.99       251
#            4       0.88      1.00      0.93        43
#
#     accuracy                           0.98       294
#    macro avg       0.94      0.99      0.96       294
# weighted avg       0.98      0.98      0.98       294

# %%
# Prediction DataFrame

pred_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})
print(pred_df.head(20))
# Out:
#       Actual  Predicted
# 1041       3          3
# 184        3          3
# 1222       3          3
# 67         3          3
# 220        3          3
# 494        3          3
# 430        3          3
# 240        3          3
# 218        3          3
# 49         3          3
# 665        3          3
# 926        3          3
# 617        3          3
# 361        3          3
# 1423       3          3
# 1244       3          3
# 1250       3          3
# 752        3          3
# 271        3          3
# 1055       3          3

# %%
import joblib

#Save the pipeline/model
joblib.dump(lr, "performance_rating_model.pkl")


#Load the saved model
loaded_model = joblib.load("performance_rating_model.pkl")

#Save the PerformanceRating feature columns
joblib.dump(list(x.columns), 'PerformanceRating_feature_columns.joblib')

#Load the PerformanceRating feature columns
feature_columns = joblib.load('PerformanceRating_feature_columns.joblib')
